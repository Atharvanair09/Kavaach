# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("final_dataset.xls")

# %%
df
# Out:
#                                                     text   category
# 0      No deagle nerf/vault, good patch but could be ...    Neutral
# 1                          Thank you Burger King! Source   Distress
# 2      I was going to suggest that it was likely a 96...    Neutral
# 3                                     Absolutely brutal.  Emergency
# 4      Damn, women really are helpless little sheep, ...    Neutral
# ...                                                  ...        ...
# 59158  Mostly because they're not completely stupid. ...  Offensive
# 59159              This show and its always sunny for me    Neutral
# 59160  [NAME] can actually be accessed via the DC uni...   Distress
# 59161                               He looks like [NAME]   Distress
# 59162                            Osaka making me nervous  Emergency
#
# [59163 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59163 entries, 0 to 59162
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      59163 non-null  object
#  1   category  59163 non-null  object
# dtypes: object(2)
# memory usage: 924.5+ KB

# %%
df["category"].value_counts()
# Out:
# category
# Distress     29521
# Neutral      17850
# Offensive     7792
# Emergency     4000
# Name: count, dtype: int64

# %%
data1 = df.to_csv("finale-data.csv", index=False)
