# %%
import numpy as np
import pandas as pd

# %%
pip install datasets
# Out:
# Requirement already satisfied: datasets in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (4.5.0)
# Requirement already satisfied: filelock in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from datasets) (3.24.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from datasets) (1.4.1)
# Requirement already satisfied: packaging in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.11.14)
# Requirement already satisfied: anyio in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->datasets) (4.9.0)
# Requirement already satisfied: certifi in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->datasets) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->datasets) (1.0.7)
# Requirement already satisfied: idna in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->datasets) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: colorama in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.18.3)
# Requirement already satisfied: six>=1.5 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: typer>=0.24.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\atharva nair\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from datasets import load_dataset

emotions = load_dataset("go_emotions")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
test = emotions["test"]
train = emotions["train"]
validation = emotions["validation"]

print(test, train, validation)
# Out:
# Dataset({
#     features: ['text', 'labels', 'id'],
#     num_rows: 5427
# }) Dataset({
#     features: ['text', 'labels', 'id'],
#     num_rows: 43410
# }) Dataset({
#     features: ['text', 'labels', 'id'],
#     num_rows: 5426
# })
